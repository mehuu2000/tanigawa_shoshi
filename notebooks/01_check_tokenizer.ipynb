# %% [markdown]
# # 01_check_tokenizer
#
# 論文方針のトークナイザを確認する。

# %%
# Notebook から src 配下の自作モジュールを import できるようにする設定
from pathlib import Path
import sys

project_root = Path.cwd().parent
src_path = project_root / "src"
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

# %%
# 自作モジュールのインポート
from tanigawa_shoshi.tokenizer import build_segments, split_units, tokenize, tokenize_values

# %% [markdown]
# #### ICU分割、セグメント生成([{type, item}, {type, item}...])、トークナイズ の実行チェック

# %%
sample = "JaLC Search-Based 2026年創業 A・B ﾃｽﾄ･ｹｰｽ 東京大学 Vol.12 No.3 pp.1-10"
units = split_units(sample)
segments = build_segments(units)
tokens = tokenize(sample)

print("units:")
print(units)

print("\nsegments:")
print("[")
for segment in segments:
    print("  {")
    print(f"    type: {segment['type']},")
    print(f"    items: {segment['items']}")
    print("  },")
print("]")

print("\ntokens:")
print(tokens)
# Out:
# units:
# ['JaLC', 'Search', 'Based', '2026', '年', '創業', 'A', 'B', 'ﾃｽﾄ', 'ｹｰｽ', '東京', '大学', 'Vol', '12', 'No', '3', 'pp', '1', '10']
#
# segments:
# [
#   {
#     type: non_japanese_seq,
#     items: ['JaLC', 'Search', 'Based', '2026']
#   },
#   {
#     type: japanese,
#     items: ['年創業']
#   },
#   {
#     type: non_japanese_seq,
#     items: ['A', 'B']
#   },
#   {
#     type: japanese,
#     items: ['ﾃｽﾄｹｰｽ東京大学']
#   },
#   {
#     type: non_japanese_seq,
#     items: ['Vol', '12', 'No', '3', 'pp', '1', '10']
#   },
# ]
#
# tokens:
# ['JaLC', 'Search', 'Based', '2026', 'JaLC Search', 'Search Based', 'Based 2026', '年創', '創業', 'A', 'B', 'A B', 'ﾃｽ', 'ｽﾄ', 'ﾄｹ', 'ｹｰ', 'ｰｽ', 'ｽ東', '東京', '京大', '大学', 'Vol', '12', 'No', '3', 'pp', '1', '10', 'Vol 12', '12 No', 'No 3', '3 pp', 'pp 1', '1 10']

# %% [markdown]
# 本番を想定した複数の値に対応した実行チェック

# %%
field_values = [
    "山田太郎",
    "Yamada Taro",
    "情報処理学会",
    "IPSJ Journal",
    "2024",
    "12",
    "3",
    "1-10",
    "ﾃｽﾄｹｰｽ",
    "A Study",
    "年",
]
print(tokenize_values(field_values))
# Out:
# ['山田', '田太', '太郎', 'Yamada', 'Taro', 'Yamada Taro', '情報', '報処', '処理', '理学', '学会', 'IPSJ', 'Journal', 'IPSJ Journal', '2024', '12', '3', '1', '10', '1 10', 'ﾃｽ', 'ｽﾄ', 'ﾄｹ', 'ｹｰ', 'ｰｽ', 'A', 'Study', 'A Study', '年']
