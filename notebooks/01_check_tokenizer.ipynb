# %% [markdown]
# # 01_check_tokenizer
#
# 論文方針のトークナイザを確認する。

# %%
from pathlib import Path
import sys

project_root = Path.cwd().parent
src_path = project_root / "src"
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

# %%
from tanigawa_shoshi.tokenizer import build_segments, split_units, tokenize, tokenize_values

# %%
sample = "JaLC Reference Coverage 2026年創業"
print(split_units(sample))
print(build_segments(split_units(sample)))
print(tokenize(sample))

# %%
field_values = ["全文検索に基づく手法", "Search-Based Reference Matching"]
print(tokenize_values(field_values))
